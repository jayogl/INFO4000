# %%
# Import Libraries
import os
from pypdf import PdfReader
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer, util
import ollama
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 from pypdf import PdfReader
#       4 from sklearn.feature_extraction.text import TfidfVectorizer
#       5 from sklearn.metrics.pairwise import cosine_similarity
#       6 from sentence_transformers import SentenceTransformer, util
# ----> 7 import ollama
#
# ModuleNotFoundError: No module named 'ollama'

# %%
# Extract Text
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        page_text = page.extract_text()
        if page_text:
            text += page_text + "\n"
    return text

# %%
# Chunking with Overlap
def chunk_text(text, chunk_size=500, overlap=50):
    chunks = []
    start = 0
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

pdf_filename = "coffee_maker.pdf"
raw_text = extract_text_from_pdf(pdf_filename)
chunks = chunk_text(raw_text, chunk_size=500, overlap=50)
print(f"--- Step 1 & 2: PDF Chunking Complete ---")
print(f"Total Chunks Created: {len(chunks)}\n")

for idx, chunk in enumerate(chunks):
    print(f"--- CHUNK {idx + 1} ---")
    print(chunk.strip())
    print("-" * 40)
# Out:
# --- Step 1 & 2: PDF Chunking Complete ---
# Total Chunks Created: 9
#
# --- CHUNK 1 ---
# BrewMaster Pro 3000
# User Manual — 12-Cup Programmable Coffee Maker, Model BM-3000
# 1. Safety Information
# Read all instructions before using the BrewMaster Pro 3000 for the first time. Keep this manual for future
# reference.
# WARNING: To reduce risk of fire, electric shock, or injury, do not immerse the power cord, plug, or base unit in
# water or any other liquid.
#
# Do not operate the appliance with a damaged cord or plug.
#
# Do not touch hot surfaces; use handles and knobs.
#
# Unplug from the outlet w
# ----------------------------------------
# --- CHUNK 2 ---
# use handles and knobs.
#
# Unplug from the outlet when not in use and before cleaning.
#
# Do not use outdoors.
#
# This appliance is not intended for use by children.
# 2. Parts Overview
# The BrewMaster Pro 3000 includes the following components: water reservoir (1.8L capacity), removable filter
# basket, glass carafe with heat-resistant handle, warming plate, control panel with LCD display, and a
# permanent gold-tone filter.
# The control panel features four buttons: POWER, BREW STRENGTH, PROGRAM, and CLOC
# ----------------------------------------
# --- CHUNK 3 ---
# r buttons: POWER, BREW STRENGTH, PROGRAM, and CLOCK. The LCD
# display shows the current time, brew strength setting, and a cup icon that flashes during brewing.
# 3. Setup and First Use
# Before first use, wash the carafe, filter basket, and permanent filter in warm, soapy water. Rinse thoroughly.
# Run one full brew cycle with water only (no coffee grounds) to clean the internal components.
# To set up your BrewMaster Pro 3000:
#
# Place the unit on a flat, dry, heat-resistant surface away from the edge o
# ----------------------------------------
# --- CHUNK 4 ---
# , dry, heat-resistant surface away from the edge of the counter.
#
# Open the reservoir lid and fill with cold water to the desired line (4 to 12 cups).
#
# Insert the permanent filter into the filter basket and close the lid.
#
# Plug the power cord into a grounded outlet.
#
# Press and hold the CLOCK button for 3 seconds, then use the arrow buttons to set the current time.
# 4. Brewing Instructions
# Add ground coffee to the filter basket — use approximately 1 tablespoon of ground coffee per cup for stand
# ----------------------------------------
# --- CHUNK 5 ---
# ly 1 tablespoon of ground coffee per cup for standard
# strength. Close the lid and place the carafe on the warming plate, making sure it is centered correctly.
#
# Press BREW STRENGTH to toggle between Regular and Bold. Press the POWER button once to begin
# brewing. The cup icon on the display will flash throughout the brew cycle. A full 12-cup pot takes approximately
# 8 to 10 minutes to brew.
# The warming plate keeps coffee hot for up to 2 hours after brewing completes, after which the unit will
# autom
# ----------------------------------------
# --- CHUNK 6 ---
# brewing completes, after which the unit will
# automatically power off to conserve energy.
# 5. Programming a Delayed Brew
# To brew coffee automatically at a future time, press PROGRAM and use the arrow buttons to set your desired
# brew start time, then press PROGRAM again to confirm. The PROGRAM indicator light will remain lit until the
# scheduled brew begins.
# 6. Cleaning and Maintenance
# Allow the unit to cool completely before cleaning. Wipe the exterior with a damp cloth. The carafe, filter basket,
# ----------------------------------------
# --- CHUNK 7 ---
# ior with a damp cloth. The carafe, filter basket,
# and permanent filter are dishwasher safe on the top rack.
# Descale the unit every 2 to 3 months, or sooner in hard water areas. Fill the reservoir with a 50/50 mixture of
# white vinegar and water, run a full brew cycle without coffee grounds, then run two additional cycles with clean
# water to rinse.
# 7. Troubleshooting
#  Problem
# Possible Cause
# Solution
# Coffee maker will not turn on
# Not plugged in properly
# Check the power cord connection and outlet
# Br
# ----------------------------------------
# --- CHUNK 8 ---
# erly
# Check the power cord connection and outlet
# Brewing is slow or incomplete
# Mineral buildup
# Descale the unit (see Section 6)
# Coffee is weak
# Incorrect coffee-to-water ratio
# Use 1 tbsp ground coffee per cup, or select Bold strength
# Overflow at filter basket
# Filter basket not seated correctly
# Remove and reinsert the filter basket firmly
# Display is unresponsive
# Unit needs a reset
# Unplug the unit for 30 seconds, then plug it back in to reset the control panel
# 8. Specifications
#  Specification
# Value
# ----------------------------------------
# --- CHUNK 9 ---
# trol panel
# 8. Specifications
#  Specification
# Value
# Capacity
# 12 cups (1.8 L)
# Power
# 900W, 120V, 60Hz
# Dimensions
# 9.5 in x 7.2 in x 12.8 in
# Weight
# 3.4 lbs
# Warranty
# 2 years limited
# ----------------------------------------

# %%
# Test Questions
questions = [
    "How often should I descale the coffee maker and what solution should I use?",
    "How long does the warming plate keep the coffee hot after brewing completes?",
    "What is the first step to set up the coffee maker?",
    "What should I do if the screen stops responding or freezes?" # Rephrased question
]

# %%
# TF-IDF Retrieval 
tfidf_vectorizer = TfidfVectorizer()
tfidf_docs_matrix = tfidf_vectorizer.fit_transform(chunks)

# Embedding Retrieval 
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
doc_embeddings = embedding_model.encode(chunks, convert_to_tensor=True)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\jayog\Documents\INFO4000\.venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\jayog\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Retrieval Comparison
print("\n" + "="*50)
print("--- RETRIEVAL COMPARISON (TF-IDF vs EMBEDDINGS) ---")
print("="*50)
best_chunks_for_rag = []

for q_idx, q in enumerate(questions, 1):
    print(f"\n[Question {q_idx}]: \"{q}\"")
    
    # TF-IDF
    q_tfidf_vec = tfidf_vectorizer.transform([q])
    tfidf_scores = cosine_similarity(q_tfidf_vec, tfidf_docs_matrix)
    best_tfidf_idx = tfidf_scores.argmax().item()
    
    # Embedding
    q_embed_vec = embedding_model.encode(q, convert_to_tensor=True)
    embed_scores = util.cos_sim(q_embed_vec, doc_embeddings)
    best_embed_idx = embed_scores.argmax().item()
    
    print(f"  • TF-IDF Top Match   : Chunk #{best_tfidf_idx + 1} (Score: {tfidf_scores[best_tfidf_idx].item():.4f})")
    print(f"  • Embedding Top Match: Chunk #{best_embed_idx + 1} (Score: {embed_scores[best_embed_idx].item():.4f})")
    
    if best_tfidf_idx == best_embed_idx:
        print("  -&gt; Result: BOTH methods retrieved the same chunk.")
    else:
        print("  -&gt; Result: DIFFERENT chunks retrieved.")
        
    best_chunks_for_rag.append((q, chunks[best_embed_idx]))
# Out:
# ==================================================
# --- RETRIEVAL COMPARISON (TF-IDF vs EMBEDDINGS) ---
# ==================================================
#
# [Question 1]: "How often should I descale the coffee maker and what solution should I use?"
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 20
#      16     q_embed_vec = embedding_model.encode(q, convert_to_tensor=True)
#      17     embed_scores = util.cos_sim(q_embed_vec, doc_embeddings)
#      18     best_embed_idx = embed_scores.argmax().item()
#      19
# ---> 20     print(f"  • TF-IDF Top Match   : Chunk #{best_tfidf_idx + 1} (Score: {tfidf_scores[best_tfidf_idx]:.4f})")
#      21     print(f"  • Embedding Top Match: Chunk #{best_embed_idx + 1} (Score: {embed_scores[best_embed_idx].item():.4f})")
#      22
#      23     if best_tfidf_idx == best_embed_idx:
#
# IndexError: index 6 is out of bounds for axis 0 with size 1

# %%
# Local LLM Generation
print("\n" + "="*50)
print("--- GENERATING GROUNDED ANSWERS WITH OLLAMA ---")
print("="*50)

for q_idx, (q, chunk_context) in enumerate(best_chunks_for_rag, 1):
    prompt = f"""You are an internal appliance support assistant. Answer the user's question using ONLY the information in the context below. If the context doesn't contain the answer, say you don't have that information.

Context:
{chunk_context}
Question:
{q}
Answer:"""
    try:
        response = ollama.generate(model="llama3.2", prompt=prompt)
        print(f"\n[Q{q_idx} Query]: {q}")
        print(f"[Generated Response]:\n{response['response'].strip()}")
        print("-" * 50)
    except Exception as e:
        print(f"Could not reach Ollama: {e}")
