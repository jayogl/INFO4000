# %%
# Import and Setup
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on device: {device}")
# Out:
# Training on device: cpu

# %%
# Data Preprocessing & Augmentation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(degrees=10),
        transforms.Lambda(lambda img: img.convert('RGB')),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.Lambda(lambda img: img.convert('RGB')),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %%
# Load Dataset using ImageFolder
data_dir = "./covid_ct"
image_datasets = {
    x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x])
    for x in ['train', 'test']
}
dataloaders = {
    x: DataLoader(image_datasets[x], batch_size=16, shuffle=(x == 'train'), num_workers=2)
    for x in ['train', 'test']
}
class_names = image_datasets['train'].classes  # Expected: ['covid', 'normal']
print(f"Loaded Classes: {class_names}")
# Out:
# Loaded Classes: ['covid', 'normal']

# %%
# Pretrained Model (ResNet18)
weights = models.ResNet18_Weights.DEFAULT
model = models.resnet18(weights=weights)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(class_names))
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\jayog/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:04<00:00, 9.92MB/s]

# %%
# Training and Validation Loop
num_epochs = 2
best_acc = 0.0
start_time = time.time()
for epoch in range(num_epochs):
    print(f"\n--- Epoch {epoch+1}/{num_epochs} ---")
    for phase in ['train', 'test']:
        if phase == 'train':
            model.train()
        else:
            model.eval()
        running_loss = 0.0
        running_corrects = 0
        for inputs, labels in dataloaders[phase]:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
        epoch_loss = running_loss / len(image_datasets[phase])
        epoch_acc = running_corrects.double() / len(image_datasets[phase])
        print(f"{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}")
        if phase == 'test' and epoch_acc > best_acc:
            best_acc = epoch_acc
            torch.save(model.state_dict(), 'covid_model.pth')
elapsed = time.time() - start_time
print(f"\nTraining completed in {elapsed // 60:.0f}m {elapsed % 60:.0f}s")
print(f"Best Test Accuracy: {best_acc:.2%}")
# Out:
# --- Epoch 1/2 ---
# C:\Users\jayog\Documents\INFO4000\.venv\Lib\site-packages\torch\utils\data\dataloader.py:438: UserWarning: Got pickle error when attempting to start a worker Process. This might be because the worker Process arguments are not picklable. Python 3.14+ changed the multiprocessing start method in non-Mac POSIX platforms to 'forkserver', which requires the worker Process arguments to be picklable. You can also try multiprocessing.set_start_method('fork').
#   return _MultiProcessingDataLoaderIter(self)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: module '__main__' has no attribute '<lambda>'
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[9], line 14
#      10         else:
#      11             model.eval()
#      12         running_loss = 0.0
#      13         running_corrects = 0
# ---> 14         for inputs, labels in dataloaders[phase]:
#      15             inputs, labels = inputs.to(device), labels.to(device)
#      16             optimizer.zero_grad()
#      17             with torch.set_grad_enabled(phase == 'train'):
#
# File ~\Documents\INFO4000\.venv\Lib\site-packages\torch\utils\data\dataloader.py:505, in DataLoader.__iter__(self)
#     503     return self._iterator
#     504 else:
# --> 505     return self._get_iterator()
#
# File ~\Documents\INFO4000\.venv\Lib\site-packages\torch\utils\data\dataloader.py:438, in DataLoader._get_iterator(self)
#     436 else:
#     437     self.check_worker_number_rationality()
# --> 438     return _MultiProcessingDataLoaderIter(self)
#
# File ~\Documents\INFO4000\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1178, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1175 from pickle import PicklingError
#    1177 try:
# -> 1178     w.start()
#    1179 except (TypeError, AttributeError, PicklingError):
#    1180     warnings.warn(
#    1181         "Got pickle error when attempting to start a worker Process. "
#    1182         "This might be because the worker Process arguments are not picklable. "
#    (...)   1186         stacklevel=2,
#    1187     )
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\multiprocessing\context.py:230, in Process._Popen(process_obj)
#     228 @staticmethod
#     229 def _Popen(process_obj):
# --> 230     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\multiprocessing\context.py:343, in SpawnProcess._Popen(process_obj)
#     340 @staticmethod
#     341 def _Popen(process_obj):
#     342     from .popen_spawn_win32 import Popen
# --> 343     return Popen(process_obj)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\multiprocessing\popen_spawn_win32.py:97, in Popen.__init__(self, process_obj)
#      95 try:
#      96     reduction.dump(prep_data, to_child)
# ---> 97     reduction.dump(process_obj, to_child)
#      98 finally:
#      99     set_spawning_popen(None)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# PicklingError: Can't pickle <function <lambda> at 0x000001989646EB90>: it's not found as __main__.<lambda>
# when serializing dict item 'lambd'
# when serializing torchvision.transforms.transforms.Lambda state
# when serializing torchvision.transforms.transforms.Lambda object
# when serializing list item 3
# when serializing dict item 'transforms'
# when serializing torchvision.transforms.transforms.Compose state
# when serializing torchvision.transforms.transforms.Compose object
# when serializing dict item 'transform'
# when serializing torchvision.datasets.folder.ImageFolder state
# when serializing torchvision.datasets.folder.ImageFolder object
# when serializing list item 0
# when serializing tuple item 1
# when serializing dict item '_args'
# when serializing multiprocessing.context.Process state
# when serializing multiprocessing.context.Process object
