# %% [markdown]
# ### Scraping from the Web using 'read_html' ###

# %%
import pandas as pd

# %% [markdown]
# ##### You may have to install a module called lxml if you get an error message for the cell below #####
#
# uv add lxml

# %%
# Read in the tables on this Wikipedia page

# Pass a custom user-agent header so Wikipedia allows the connection
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
tables = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', storage_options=headers)

# Check how many tables have been read in
print(f"no_of_tables_retrieved = {len(tables)}")
# Out:
# no_of_tables_retrieved = 29

# %%
# Assign any one of the table to a variable and 

df = tables[5]
print(f"Table number 5 in DataFrame format:\n\n{df}")
# Out:
# Table number 5 in DataFrame format:
#
#           Race / Ethnicity (NH = Non-Hispanic)  Pop 2000[92]  Pop 2010[93]  \
# 0                             White alone (NH)       4337143       4405142
# 1         Black or African American alone (NH)        168813        269141
# 2  Native American or Alaska Native alone (NH)         52009         55421
# 3                             Asian alone (NH)        141083        212996
# 4                  Pacific Islander alone (NH)          1714          1860
# 5                        Other race alone (NH)          5031          5947
# 6               Mixed race or Multiracial (NH)         70304        103160
# 7                Hispanic or Latino (any race)        143382        250258
# 8                                        Total       4919479       5303925
#
#    Pop 2020[94]   % 2000   % 2010   % 2020
# 0       4353880   88.16%   83.05%   76.30%
# 1        392850    3.43%    5.07%    6.88%
# 2         57046    1.06%    1.04%    1.00%
# 3        297460    2.87%    4.02%    5.21%
# 4          2621    0.03%    0.04%    0.05%
# 5         20963    0.10%    0.11%    0.37%
# 6        236034    1.43%    1.94%    4.14%
# 7        345640    2.91%    4.72%    6.06%
# 8       5706494  100.00%  100.00%  100.00%

# %%
# With 38 tables, it can be challenging to find the one you need. 
# To make the table selection easier, use the match parameter to select a subset of tables. 
# We can use the caption “United States presidential election results for Minnesota” to select the table

# Read in from Wikipedia page, skiprows if there are multiple hearder rows, let row0 be the header and take the first table (from list of tables)
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
table = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', storage_options=headers,match='United States presidential election results for Minnesota',skiprows=1,header=0)[0]

# Assign df1
df1 = table
# Check type of data structure
print(f"Data type: {type(df1)}\n")

# Rename columns
df1 = df1.rename(columns={'No.':'Republican','%':'R%','No..1':'Democratic','%.1':'D%','No..2':'Third Party','%.2':'T%'})

# Take a look
print(f"The dataframe:\n\n{df1.head()}\n\nIt's shape: {df1.shape}\n\nThe index: {df1.index}")
# Out:
# Data type: <class 'pandas.DataFrame'>
#
# The dataframe:
#
#    Year  Republican      R%  Democratic      D%  Third Party     T%
# 0  1860       22069  63.53%       11920  34.31%          748  2.15%
# 1  1864       25055  59.06%       17367  40.94%            0  0.00%
# 2  1868       43722  60.88%       28096  39.12%            0  0.00%
# 3  1872       55708  61.27%       35211  38.73%            0  0.00%
# 4  1876       72955  58.80%       48587  39.16%         2533  2.04%
#
# It's shape: (42, 7)
#
# The index: RangeIndex(start=0, stop=42, step=1)

# %%
# Gather info and check the datatypes of the individual columns
print(df1.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         42 non-null     int64
#  1   Republican   42 non-null     int64
#  2   R%           42 non-null     str
#  3   Democratic   42 non-null     int64
#  4   D%           42 non-null     str
#  5   Third Party  42 non-null     int64
#  6   T%           42 non-null     str
# dtypes: int64(4), str(3)
# memory usage: 3.1 KB
# None

# %%
# We need to convert the % columns to numeric values if we want to do any analysis.
# Doing df1['R%'].astype('float') does not work as there is the % sign with the numbers, so we need to remove that

df1[['D%','R%']].replace({'%':''}, regex=True).astype('float')
# Out:
#        D%     R%
# 0   34.31  63.53
# 1   40.94  59.06
# 2   39.12  60.88
# 3   38.73  61.27
# 4   39.16  58.80
# 5   35.36  62.28
# 6   36.87  58.78
# 7   39.65  54.12
# 8   37.76  45.96
# 9   40.89  56.62
# 10  35.69  60.21
# 11  18.84  73.98
# 12  33.02  59.11
# 13  31.84  19.25
# 14  46.25  46.35
# 15  19.43  70.59
# 16   6.80  51.18
# 17  40.83  57.77
# 18  59.91  36.29
# 19  61.84  31.01
# 20  51.49  47.66
# 21  52.41  46.86
# 22  57.16  39.89
# 23  44.11  55.33
# 24  46.08  53.68
# 25  50.58  49.16
# 26  63.76  36.00
# 27  54.00  41.46
# 28  46.07  51.58
# 29  54.90  42.02
# 30  46.50  42.56
# 31  49.72  49.54
# 32  52.91  45.90
# 33  43.48  31.85
# 34  51.10  34.96
# 35  47.91  45.50
# 36  51.09  47.61
# 37  54.06  43.82
# 38  52.65  44.96
# 39  46.44  44.93
# 40  52.40  45.28
# 41  50.92  46.68
