# %% [markdown]
# ### Using 'requests' module to access APIs ###

# %%
import requests
import json

# %%
# People in space on ISS

url_astro = "http://api.open-notify.org/astros.json"

astros = requests.request("GET",url_astro)
print(f"Response Status Code:{astros}\n")

result2 = json.loads(astros.text) # Assign content of response to a variable
print(f" Response Text:\n{result2}\n")
print(f"Dict keys in response:\n{result2.keys()}\n")
print(f"\nNumber of astros on ISS\n{result2['number']}\n")

who = result2['people']

print(f"\nAstros on board ISS\n")
for i in who:
    print(i['name'])
# Out:
# Response Status Code:<Response [200]>
#
#  Response Text:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'}, {'craft': 'ISS', 'name': 'Nikolai Chub'}, {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'}, {'craft': 'ISS', 'name': 'Matthew Dominick'}, {'craft': 'ISS', 'name': 'Michael Barratt'}, {'craft': 'ISS', 'name': 'Jeanette Epps'}, {'craft': 'ISS', 'name': 'Alexander Grebenkin'}, {'craft': 'ISS', 'name': 'Butch Wilmore'}, {'craft': 'ISS', 'name': 'Sunita Williams'}, {'craft': 'Tiangong', 'name': 'Li Guangsu'}, {'craft': 'Tiangong', 'name': 'Li Cong'}, {'craft': 'Tiangong', 'name': 'Ye Guangfu'}], 'number': 12, 'message': 'success'}
#
# Dict keys in response:
# dict_keys(['people', 'number', 'message'])
#
#
# Number of astros on ISS
# 12
#
#
# Astros on board ISS
#
# Oleg Kononenko
# Nikolai Chub
# Tracy Caldwell Dyson
# Matthew Dominick
# Michael Barratt
# Jeanette Epps
# Alexander Grebenkin
# Butch Wilmore
# Sunita Williams
# Li Guangsu
# Li Cong
# Ye Guangfu

# %%
# Accessing another NASA API - p0sition of ISS

url_nasa = "http://api.open-notify.org/iss-now.json"

position = requests.request("GET",url_nasa)
print(f"Status Code:{position}\n")
print(position.headers)
result1 = json.loads(position.text)
print(f"\nKeys:\n{result1.keys()}")
print(result1)
# Out:
# Status Code:<Response [200]>
#
# {'Server': 'nginx/1.10.3', 'Date': 'Wed, 26 Aug 2026 00:09:49 GMT', 'Content-Type': 'application/json', 'Content-Length': '113', 'Connection': 'keep-alive', 'access-control-allow-origin': '*'}
#
# Keys:
# dict_keys(['message', 'iss_position', 'timestamp'])
# {'message': 'success', 'iss_position': {'latitude': '10.0662', 'longitude': '-14.8876'}, 'timestamp': 1787702989}
